# %% [markdown]
# # Geocoding

# %%
import requests

def geocode(address):
    res = requests.get(f"https://geocode.xyz/{address}", params={"json":1})
    data = res.json()
    return {
        "type":"Point",
        "coordinates":[float(data["longt"]),float(data["latt"])]
    }

# %%
# https://geojson.io/#map=16/40.3959/-3.7039
# https://geojson.org/
ironhack = "Paseo de la chopera 14 Madrid"
geocode(ironhack)
# Out:
# {'type': 'Point', 'coordinates': [-3.7011, 40.39652]}

# %% [markdown]
# # Mongodb queries

# %%
# https://docs.mongodb.com/manual/reference/operator/query/near/#op._S_near

# %%
from pymongo import MongoClient

client = MongoClient("mongodb://localhost/datamad0620")
db = client.get_database()

# %%
import re

n = re.compile("^face",re.IGNORECASE)
companies = db.companies.find({"name":n},{"offices":1, "name":1})

# %%
import pandas as pd

df = pd.DataFrame(list(companies))
df
# Out:
#                          _id                         name  \
# 0   52cdef7c4bab8bd675297d8e                     Facebook
# 1   52cdef7c4bab8bd675298334                      FaceTec
# 2   52cdef7d4bab8bd675299497              Face Your Manga
# 3   52cdef7d4bab8bd675299d49                 Facebookster
# 4   52cdef7d4bab8bd67529a044                   FACEinHOLE
# 5   52cdef7d4bab8bd67529a054  Facebook Causes Application
# 6   52cdef7d4bab8bd67529a1b9                      FaceKoo
# 7   52cdef7e4bab8bd67529a7c9                     facetime
# 8   52cdef7e4bab8bd67529aaa9               facelovefinder
# 9   52cdef7e4bab8bd67529ab2a                  FACE Africa
# 10  52cdef7f4bab8bd67529c4a8             FacebookLicious!
# 11  52cdef7f4bab8bd67529c661            FaceTime Strategy
#
#                                               offices
# 0   [{'description': 'Headquarters', 'address1': '...
# 1   [{'description': None, 'address1': 'Liverpool ...
# 2                                                  []
# 3   [{'description': 'Facebookster US Office', 'ad...
# 4   [{'description': 'Headquarters', 'address1': '...
# 5                                                  []
# 6   [{'description': '', 'address1': 'No. 18, Daji...
# 7                                                  []
# 8   [{'description': '', 'address1': 'Manzanos 151...
# 9   [{'description': 'Main Office', 'address1': '9...
# 10  [{'description': 'Facebooklicious Office.', 'a...
# 11                                                 []

# %%
offices = df.explode("offices").apply(lambda e: e.offices,axis=1,result_type="expand")
offices
# Out:
#                 description                  address1               address2  \
# 0              Headquarters          1601 Willow Road
# 0                 Europe HQ
# 0                  New York           340 Madison Ave
# 1                      None    Liverpool Science Park     131 Mount Pleasant
# 2                       NaN                       NaN                    NaN
# 3    Facebookster US Office       44288 Fremont Blvd.
# 4              Headquarters                            Rua Serpa Pinto, nº 1
# 5                       NaN                       NaN                    NaN
# 6                                      No. 18, Dajie,      Chaoyang District
# 7                       NaN                       NaN                    NaN
# 8                                      Manzanos 151-C    Col. Torreon Jardin
# 9               Main Office  929 Massachusetts Avenue               Suite 01
# 10  Facebooklicious Office.        42 Paisley Street,
# 11                      NaN                       NaN                    NaN
#
#     zip_code               city state_code country_code   latitude   longitude
# 0      94025         Menlo Park         CA          USA  37.416050 -122.151801
# 0                        Dublin       None          IRL  53.344104   -6.267494
# 0      10017           New York         NY          USA  40.755716  -73.979247
# 1                     Liverpool       None          GBR        NaN         NaN
# 2        NaN                NaN        NaN          NaN        NaN         NaN
# 3      94538            Fremont         CA          USA  37.506206 -121.949247
# 4   1200-442             Lisbon       None          PRT  38.707163   -9.135517
# 5        NaN                NaN        NaN          NaN        NaN         NaN
# 6     100020            Beijing       None          CHN        NaN         NaN
# 7        NaN                NaN        NaN          NaN        NaN         NaN
# 8             Torreon, Coahuila       None          MEX  25.523006 -103.417446
# 9      02139          Cambridge         MA          USA  42.368905  -71.108999
# 10     19701               Bear         DE          USA  39.612223  -75.696706
# 11       NaN                NaN        NaN          NaN        NaN         NaN

# %%
clean_offices = pd.concat([df[["name","_id"]], offices], axis=1)
clean_offices
# Out:
#                            name                       _id  \
# 0                      Facebook  52cdef7c4bab8bd675297d8e
# 0                      Facebook  52cdef7c4bab8bd675297d8e
# 0                      Facebook  52cdef7c4bab8bd675297d8e
# 1                       FaceTec  52cdef7c4bab8bd675298334
# 2               Face Your Manga  52cdef7d4bab8bd675299497
# 3                  Facebookster  52cdef7d4bab8bd675299d49
# 4                    FACEinHOLE  52cdef7d4bab8bd67529a044
# 5   Facebook Causes Application  52cdef7d4bab8bd67529a054
# 6                       FaceKoo  52cdef7d4bab8bd67529a1b9
# 7                      facetime  52cdef7e4bab8bd67529a7c9
# 8                facelovefinder  52cdef7e4bab8bd67529aaa9
# 9                   FACE Africa  52cdef7e4bab8bd67529ab2a
# 10             FacebookLicious!  52cdef7f4bab8bd67529c4a8
# 11            FaceTime Strategy  52cdef7f4bab8bd67529c661
#
#                 description                  address1               address2  \
# 0              Headquarters          1601 Willow Road
# 0                 Europe HQ
# 0                  New York           340 Madison Ave
# 1                      None    Liverpool Science Park     131 Mount Pleasant
# 2                       NaN                       NaN                    NaN
# 3    Facebookster US Office       44288 Fremont Blvd.
# 4              Headquarters                            Rua Serpa Pinto, nº 1
# 5                       NaN                       NaN                    NaN
# 6                                      No. 18, Dajie,      Chaoyang District
# 7                       NaN                       NaN                    NaN
# 8                                      Manzanos 151-C    Col. Torreon Jardin
# 9               Main Office  929 Massachusetts Avenue               Suite 01
# 10  Facebooklicious Office.        42 Paisley Street,
# 11                      NaN                       NaN                    NaN
#
#     zip_code               city state_code country_code   latitude   longitude
# 0      94025         Menlo Park         CA          USA  37.416050 -122.151801
# 0                        Dublin       None          IRL  53.344104   -6.267494
# 0      10017           New York         NY          USA  40.755716  -73.979247
# 1                     Liverpool       None          GBR        NaN         NaN
# 2        NaN                NaN        NaN          NaN        NaN         NaN
# 3      94538            Fremont         CA          USA  37.506206 -121.949247
# 4   1200-442             Lisbon       None          PRT  38.707163   -9.135517
# 5        NaN                NaN        NaN          NaN        NaN         NaN
# 6     100020            Beijing       None          CHN        NaN         NaN
# 7        NaN                NaN        NaN          NaN        NaN         NaN
# 8             Torreon, Coahuila       None          MEX  25.523006 -103.417446
# 9      02139          Cambridge         MA          USA  42.368905  -71.108999
# 10     19701               Bear         DE          USA  39.612223  -75.696706
# 11       NaN                NaN        NaN          NaN        NaN         NaN

# %%
import numpy as np

def transformToGeoPoint(s):
    if np.isnan(s.latitude) or np.isnan(s.longitude):
        return None
    return {
        "type":"Point",
        "coordinates":[s.longitude, s.latitude]
    }
    

clean_offices["geopoint"] = clean_offices.apply(transformToGeoPoint, axis=1)

# %%
clean_offices
# Out:
#                            name                       _id  \
# 0                      Facebook  52cdef7c4bab8bd675297d8e
# 0                      Facebook  52cdef7c4bab8bd675297d8e
# 0                      Facebook  52cdef7c4bab8bd675297d8e
# 1                       FaceTec  52cdef7c4bab8bd675298334
# 2               Face Your Manga  52cdef7d4bab8bd675299497
# 3                  Facebookster  52cdef7d4bab8bd675299d49
# 4                    FACEinHOLE  52cdef7d4bab8bd67529a044
# 5   Facebook Causes Application  52cdef7d4bab8bd67529a054
# 6                       FaceKoo  52cdef7d4bab8bd67529a1b9
# 7                      facetime  52cdef7e4bab8bd67529a7c9
# 8                facelovefinder  52cdef7e4bab8bd67529aaa9
# 9                   FACE Africa  52cdef7e4bab8bd67529ab2a
# 10             FacebookLicious!  52cdef7f4bab8bd67529c4a8
# 11            FaceTime Strategy  52cdef7f4bab8bd67529c661
#
#                 description                  address1               address2  \
# 0              Headquarters          1601 Willow Road
# 0                 Europe HQ
# 0                  New York           340 Madison Ave
# 1                      None    Liverpool Science Park     131 Mount Pleasant
# 2                       NaN                       NaN                    NaN
# 3    Facebookster US Office       44288 Fremont Blvd.
# 4              Headquarters                            Rua Serpa Pinto, nº 1
# 5                       NaN                       NaN                    NaN
# 6                                      No. 18, Dajie,      Chaoyang District
# 7                       NaN                       NaN                    NaN
# 8                                      Manzanos 151-C    Col. Torreon Jardin
# 9               Main Office  929 Massachusetts Avenue               Suite 01
# 10  Facebooklicious Office.        42 Paisley Street,
# 11                      NaN                       NaN                    NaN
#
#     zip_code               city state_code country_code   latitude  \
# 0      94025         Menlo Park         CA          USA  37.416050
# 0                        Dublin       None          IRL  53.344104
# 0      10017           New York         NY          USA  40.755716
# 1                     Liverpool       None          GBR        NaN
# 2        NaN                NaN        NaN          NaN        NaN
# 3      94538            Fremont         CA          USA  37.506206
# 4   1200-442             Lisbon       None          PRT  38.707163
# 5        NaN                NaN        NaN          NaN        NaN
# 6     100020            Beijing       None          CHN        NaN
# 7        NaN                NaN        NaN          NaN        NaN
# 8             Torreon, Coahuila       None          MEX  25.523006
# 9      02139          Cambridge         MA          USA  42.368905
# 10     19701               Bear         DE          USA  39.612223
# 11       NaN                NaN        NaN          NaN        NaN
#
#      longitude                                           geopoint
# 0  -122.151801  {'type': 'Point', 'coordinates': [-122.151801,...
# 0    -6.267494  {'type': 'Point', 'coordinates': [-6.267494, 5...
# 0   -73.979247  {'type': 'Point', 'coordinates': [-73.9792469,...
# 1          NaN                                               None
# 2          NaN                                               None
# 3  -121.949247  {'type': 'Point', 'coordinates': [-121.949247,...
# 4    -9.135517  {'type': 'Point', 'coordinates': [-9.135517, 3...
# 5          NaN                                               None
# 6          NaN                                               None
# 7          NaN                                               None
# 8  -103.417446  {'type': 'Point', 'coordinates': [-103.4174464...
# 9   -71.108999  {'type': 'Point', 'coordinates': [-71.108999, ...
# 10  -75.696706  {'type': 'Point', 'coordinates': [-75.696706, ...
# 11         NaN                                               None

# %%
# Transform all companies documents to office documents

companies = db.companies.find({},{"offices":1, "name":1})
df = pd.DataFrame(list(companies))
offices = df.explode("offices").apply(lambda e: e.offices,axis=1,result_type="expand")
clean_offices = pd.concat([df[["name","_id"]], offices], axis=1)
clean_offices["geopoint"] = clean_offices.apply(transformToGeoPoint, axis=1)
# Out:
#         name                       _id   description  \
# 0       Zoho  52cdef7c4bab8bd675297d8c  Headquarters
# 1   Wetpaint  52cdef7c4bab8bd675297d8a
# 1   Wetpaint  52cdef7c4bab8bd675297d8a
# 2  AdventNet  52cdef7c4bab8bd675297d8b  Headquarters
# 3    Postini  52cdef7c4bab8bd675297d90          None
#
#                      address1    address2 zip_code        city state_code  \
# 0             4900 Hopyard Rd   Suite 310    94588  Pleasanton         CA
# 1            710 - 2nd Avenue  Suite 1100    98104     Seattle         WA
# 1        270 Lafayette Street   Suite 505    10012    New York         NY
# 2            4900 Hopyard Rd.   Suite 310    94588  Pleasanton         CA
# 3  959 Skyway Road, Suite 200        None    94070  San Carlos         CA
#
#   country_code   latitude   longitude  \
# 0          USA  37.692934 -121.904945
# 1          USA  47.603122 -122.333253
# 1          USA  40.723731  -73.996431
# 2          USA  37.692934 -121.904945
# 3          USA  37.506885 -122.247573
#
#                                             geopoint
# 0  {'type': 'Point', 'coordinates': [-121.904945,...
# 1  {'type': 'Point', 'coordinates': [-122.333253,...
# 1  {'type': 'Point', 'coordinates': [-73.9964312,...
# 2  {'type': 'Point', 'coordinates': [-121.904945,...
# 3  {'type': 'Point', 'coordinates': [-122.247573,...

# %%
clean_offices = clean_offices.rename(columns={"_id":"company_id"})
clean_offices.head()
# Out:
#         name                company_id   description  \
# 0       Zoho  52cdef7c4bab8bd675297d8c  Headquarters
# 1   Wetpaint  52cdef7c4bab8bd675297d8a
# 1   Wetpaint  52cdef7c4bab8bd675297d8a
# 2  AdventNet  52cdef7c4bab8bd675297d8b  Headquarters
# 3    Postini  52cdef7c4bab8bd675297d90          None
#
#                      address1    address2 zip_code        city state_code  \
# 0             4900 Hopyard Rd   Suite 310    94588  Pleasanton         CA
# 1            710 - 2nd Avenue  Suite 1100    98104     Seattle         WA
# 1        270 Lafayette Street   Suite 505    10012    New York         NY
# 2            4900 Hopyard Rd.   Suite 310    94588  Pleasanton         CA
# 3  959 Skyway Road, Suite 200        None    94070  San Carlos         CA
#
#   country_code   latitude   longitude  \
# 0          USA  37.692934 -121.904945
# 1          USA  47.603122 -122.333253
# 1          USA  40.723731  -73.996431
# 2          USA  37.692934 -121.904945
# 3          USA  37.506885 -122.247573
#
#                                             geopoint
# 0  {'type': 'Point', 'coordinates': [-121.904945,...
# 1  {'type': 'Point', 'coordinates': [-122.333253,...
# 1  {'type': 'Point', 'coordinates': [-73.9964312,...
# 2  {'type': 'Point', 'coordinates': [-121.904945,...
# 3  {'type': 'Point', 'coordinates': [-122.247573,...

# %%
# Convert objectIds to string to be able to export as JSON 

clean_offices["company_id"] = clean_offices["company_id"].apply(lambda e: str(e))

# Export as json records to import with mongoimport 
clean_offices.to_json("data/offices.json",orient="records")

# mongoimport -d datamad0620 -c offices --jsonArray offices.json

# %% [markdown]
# ## Mongodb geospartial `$near`

# %%
times_square = geocode("Times Square, New York")
times_square
# Out:
# {'type': 'Point', 'coordinates': [-73.98964, 40.75677]}

# %% [markdown]
# ```
# {
#    <location field>: {
#      $near: {
#        $geometry: {
#           type: "Point" ,
#           coordinates: [ <longitude> , <latitude> ]
#        },
#        $maxDistance: <distance in meters>,
#        $minDistance: <distance in meters>
#      }
#    }
# }
# ```

# %%
def geoQueryNear(point,radius=10000):
    return {
        "geopoint":{
            "$near": {
                "$geometry": point,
                "$maxDistance": radius,
                "$minDistance": 0
            }
        }
    }

# %%
q = db.offices.find(geoQueryNear(times_square, radius=3000),{"_id":0,"company_id":0})
near_offices = list(q)
len(near_offices)
# Out:
# 441

# %%
df = pd.DataFrame(near_offices)
df.to_json("data/offices_near_times_square.json",orient="records")
