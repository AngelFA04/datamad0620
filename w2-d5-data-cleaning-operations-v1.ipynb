# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data/vehicles/vehicles_messy.csv')
df.head()
# Out:
# /usr/local/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3018: DtypeWarning: Columns (70,71,72,73,74,76,79) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    barrels08  barrelsA08  charge120  charge240  city08  city08U  cityA08  \
# 0  15.695714         0.0        0.0        0.0      19      0.0        0
# 1  29.964545         0.0        0.0        0.0       9      0.0        0
# 2  12.207778         0.0        0.0        0.0      23      0.0        0
# 3  29.964545         0.0        0.0        0.0      10      0.0        0
# 4  17.347895         0.0        0.0        0.0      17      0.0        0
#
#    cityA08U  cityCD  cityE  ...  mfrCode  c240Dscr  charge240b  c240bDscr  \
# 0       0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
# 1       0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
# ...

# %%
df.describe().T
# Out:
#                    count          mean           std       min         25%  \
# barrels08        37843.0     17.532506      4.575950      0.06    14.33087
# barrelsA08       37843.0      0.216169      1.141527      0.00     0.00000
# charge120        37843.0      0.000000      0.000000      0.00     0.00000
# charge240        37843.0      0.023531      0.427647      0.00     0.00000
# city08           37843.0     17.941389      6.660360      6.00    15.00000
# city08U          37843.0      4.042737      9.645820      0.00     0.00000
# cityA08          37843.0      0.520149      3.837874      0.00     0.00000
# cityA08U         37843.0      0.327163      3.542596      0.00     0.00000
# cityCD           37843.0      0.000406      0.039918      0.00     0.00000
# cityE            37843.0      0.184790      2.904558      0.00     0.00000
# cityUF           37843.0      0.000706      0.019458      0.00     0.00000
# ...

# %%
df.shape
# Out:
# (37843, 83)

# %%
df.columns
# Out:
# Index(['barrels08', 'barrelsA08', 'charge120', 'charge240', 'city08',
#        'city08U', 'cityA08', 'cityA08U', 'cityCD', 'cityE', 'cityUF', 'co2',
#        'co2A', 'co2TailpipeAGpm', 'co2TailpipeGpm', 'comb08', 'comb08U',
#        'combA08', 'combA08U', 'combE', 'combinedCD', 'combinedUF', 'cylinders',
#        'displ', 'drive', 'engId', 'eng_dscr', 'feScore', 'fuelCost08',
#        'fuelCostA08', 'fuelType', 'fuelType1', 'ghgScore', 'ghgScoreA',
#        'highway08', 'highway08U', 'highwayA08', 'highwayA08U', 'highwayCD',
#        'highwayE', 'highwayUF', 'hlv', 'hpv', 'id', 'lv2', 'lv4', 'make',
#        'model', 'mpgData', 'phevBlended', 'pv2', 'pv4', 'range', 'rangeCity',
#        'rangeCityA', 'rangeHwy', 'rangeHwyA', 'trany', 'UCity', 'UCityA',
#        'UHighway', 'UHighwayA', 'VClass', 'year', 'youSaveSpend', 'guzzler',
#        'trans_dscr', 'tCharger', 'sCharger', 'atvType', 'fuelType2', 'rangeA',
#        'evMotor', 'mfrCode', 'c240Dscr', 'charge240b', 'c240bDscr',
# ...

# %%
df[["make","model","co2","year","trany"]]
# Out:
#              make                model  co2  year            trany
# 0      Alfa Romeo   Spider Veloce 2000   -1  1985     Manual 5-spd
# 1         Ferrari           Testarossa   -1  1985     Manual 5-spd
# 2           Dodge              Charger   -1  1985     Manual 5-spd
# 3           Dodge  B150/B250 Wagon 2WD   -1  1985  Automatic 3-spd
# 4          Subaru     Legacy AWD Turbo   -1  1993     Manual 5-spd
# ...           ...                  ...  ...   ...              ...
# 37838      Subaru               Legacy   -1  1993  Automatic 4-spd
# 37839      Subaru               Legacy   -1  1993     Manual 5-spd
# 37840      Subaru           Legacy AWD   -1  1993  Automatic 4-spd
# 37841      Subaru           Legacy AWD   -1  1993     Manual 5-spd
# 37842      Subaru     Legacy AWD Turbo   -1  1993  Automatic 4-spd
#
# [37843 rows x 5 columns]

# %%
df.isnull().sum().sort_values(ascending=False).head(20)
# Out:
# c240bDscr     37807
# c240Dscr      37806
# evMotor       37281
# sCharger      37177
# rangeA        36440
# fuelType2     36435
# guzzler       35562
# atvType       34771
# tCharger      32657
# startStop     31705
# mfrCode       30818
# trans_dscr    22796
# eng_dscr      15403
# drive          1189
# cylinders       123
# displ           120
# trany            11
# engId             0
# combinedUF        0
# combinedCD        0
# dtype: int64

# %%
valid_columns = df.isnull().sum().sort_values(ascending=False) == 0
valid_columns
# Out:
# c240bDscr      False
# c240Dscr       False
# evMotor        False
# sCharger       False
# rangeA         False
#                ...
# highwayUF       True
# highwayE        True
# highwayCD       True
# highwayA08U     True
# barrels08       True
# Length: 83, dtype: bool

# %%
valid_columns = [colName for colName,isValid in valid_columns.items() if isValid]
#df_clean = df[valid_columns]

# %%
valid_columns.append("trany")
valid_columns.append("cylinders")

# %%
df.trany.value_counts()
# Out:
# Automatic 4-spd                     11042
# Manual 5-spd                         8311
# Automatic 3-spd                      3151
# Automatic (S6)                       2638
# Manual 6-spd                         2429
# Automatic 5-spd                      2184
# Manual 4-spd                         1483
# Automatic 6-spd                      1432
# Automatic (S8)                        960
# Automatic (S5)                        824
# Automatic (variable gear ratios)      681
# Automatic 7-spd                       663
# Automatic (S7)                        261
# Auto(AM-S7)                           256
# Automatic 8-spd                       243
# Automatic (S4)                        233
# Auto(AM7)                             160
# Auto(AV-S6)                           145
# Auto(AM6)                             110
# Automatic (A1)                        109
# Auto(AM-S6)                            92
# Automatic 9-spd                        90
# ...

# %%
df.trany.str.startswith("A")
#df["tipo_transmision"] =
# Out:
# 0        False
# 1        False
# 2        False
# 3         True
# 4        False
#          ...
# 37838     True
# 37839    False
# 37840     True
# 37841    False
# 37842     True
# Name: trany, Length: 37843, dtype: object

# %%
df_clean=df[valid_columns]

# %%
df_clean.isnull().sum()
# Out:
# engId            0
# combinedUF       0
# combinedCD       0
# combE            0
# phevComb         0
#               ...
# highwayCD        0
# highwayA08U      0
# barrels08        0
# trany           11
# cylinders      123
# Length: 68, dtype: int64

# %%
df_clean["trany"] = df_clean.trany.fillna("no-transmision")
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_clean.isnull().sum()
# Out:
# engId            0
# combinedUF       0
# combinedCD       0
# combE            0
# phevComb         0
#               ...
# highwayCD        0
# highwayA08U      0
# barrels08        0
# trany            0
# cylinders      123
# Length: 68, dtype: int64

# %%
df_clean["tipo_transmision"] = df_clean.trany.str.startswith("A")
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_clean["tipo_transmision"] = np.where(df_clean.trany.str.startswith("A"), "Auto", "Manual")
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_clean["tipo_transmision"].value_counts()
# Out:
# Auto      25443
# Manual    12400
# Name: tipo_transmision, dtype: int64

# %%
df_clean
# Out:
#        engId  combinedUF  combinedCD  combE  phevComb  feScore  fuelCost08  \
# 0       9011         0.0         0.0    0.0         0       -1        1600
# 1      22020         0.0         0.0    0.0         0       -1        3050
# 2       2100         0.0         0.0    0.0         0       -1        1250
# 3       2850         0.0         0.0    0.0         0       -1        3050
# 4      66031         0.0         0.0    0.0         0       -1        2150
# ...      ...         ...         ...    ...       ...      ...         ...
# 37838  66030         0.0         0.0    0.0         0       -1        1500
# 37839  66030         0.0         0.0    0.0         0       -1        1450
# 37840  66030         0.0         0.0    0.0         0       -1        1600
# 37841  66030         0.0         0.0    0.0         0       -1        1600
# 37842  66031         0.0         0.0    0.0         0       -1        2250
#
# ...

# %%
coches_caros = df_clean[(df_clean["make"]== "Audi") | (df_clean["make"]== "Lamborghini")]
coches_caros.tipo_transmision.value_counts()
# Out:
# Auto      686
# Manual    339
# Name: tipo_transmision, dtype: int64

# %%
df_clean["tipo_trany_2"] = df_clean.trany
df_clean["tipo_trany_2"][df_clean.trany.str.startswith("A")] = "Automatico"
df_clean["tipo_trany_2"][df_clean.trany.str.startswith("M")] = "Manual"
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/site-packages/pandas/core/generic.py:8767: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
df_clean["tipo_trany_2"].value_counts()
# Out:
# Automatico        25443
# Manual            12389
# no-transmision       11
# Name: tipo_trany_2, dtype: int64

# %%
cars = df_clean[["make","model","co2","year","tipo_trany_2","fuelType","cylinders"]]

# %%
cars.fuelType.value_counts()
# Out:
# Regular                        25076
# Premium                        10004
# Gasoline or E85                 1204
# Diesel                          1101
# Premium or E85                   121
# Electricity                      120
# Midgrade                          74
# CNG                               60
# Premium and Electricity           20
# Gasoline or natural gas           20
# Premium Gas or Electricity        17
# Regular Gas and Electricity       16
# Gasoline or propane                8
# Regular Gas or Electricity         2
# Name: fuelType, dtype: int64

# %%
# %matplotlib inline
cars.year.value_counts().sort_index().plot.bar()

# %%
cars.groupby("year").agg({"make":"count"})
# Out:
#       make
# year
# 1984  1964
# 1985  1701
# 1986  1210
# 1987  1247
# 1988  1130
# 1989  1153
# 1990  1078
# 1991  1132
# 1992  1121
# 1993  1093
# 1994   982
# 1995   967
# 1996   773
# 1997   762
# 1998   812
# 1999   852
# 2000   840
# 2001   911
# 2002   975
# 2003  1044
# 2004  1122
# 2005  1166
# 2006  1104
# 2007  1126
# 2008  1187
# 2009  1184
# 2010  1109
# 2011  1130
# 2012  1153
# 2013  1185
# 2014  1226
# 2015  1283
# 2016  1258
# 2017   863

# %%
cars_make_count_by_year = cars.groupby(["year","make"]).agg({"make":"count"})
cars_make_count_by_year
# Out:
#                                   make
# year make
# 1984 AM General                      4
#      Alfa Romeo                      4
#      American Motors Corporation    20
#      Aston Martin                    6
#      Audi                           26
# ...                                ...
# 2017 Subaru                         14
#      Toyota                         41
#      Volkswagen                     20
#      Volvo                          21
#      smart                           2
#
# [1628 rows x 1 columns]

# %%
cars_make_count_by_year = cars_make_count_by_year.rename(columns={"make":"make_count"})
cars_make_count_by_year.loc[2008].sort_values(by="make_count",ascending=False).head(5)
# Out:
#            make_count
# make
# Chevrolet          98
# BMW                77
# Dodge              65
# GMC                57
# Ford               54

# %%
cars_make_count_by_year.rename(columns={"make":"make_count"})
# Out:
#                                   make_count
# year make
# 1984 AM General                            4
#      Alfa Romeo                            4
#      American Motors Corporation          20
#      Aston Martin                          6
#      Audi                                 26
# ...                                      ...
# 2017 Subaru                               14
#      Toyota                               41
#      Volkswagen                           20
#      Volvo                                21
#      smart                                 2
#
# [1628 rows x 1 columns]

# %%
cars.groupby(["year"]).agg({"co2":"mean"})
# Out:
#              co2
# year
# 1984   -1.000000
# 1985   -1.000000
# 1986   -1.000000
# 1987   -1.000000
# 1988   -1.000000
# 1989   -1.000000
# 1990   -1.000000
# 1991   -1.000000
# 1992   -1.000000
# 1993   -1.000000
# 1994   -1.000000
# 1995   -1.000000
# 1996   -1.000000
# 1997   -1.000000
# 1998   -0.996305
# 1999   -0.991784
# 2000   -0.995238
# 2001   -0.994512
# 2002   -0.997949
# 2003   -0.999042
# 2004   -1.000000
# 2005   -1.000000
# 2006   -1.000000
# 2007   -1.000000
# 2008   -0.999158
# 2009   -1.000000
# 2010   -1.000000
# 2011   -0.921239
# 2012   -0.652212
# 2013  418.766245
# 2014  412.768352
# 2015  402.823850
# 2016  390.819555
# 2017  403.515643

# %%
cars_with_co2_measure = cars[cars.co2 > 0]

# %%
cars_with_co2_measure.groupby(["year"]).agg({"co2":"mean"})
# Out:
#              co2
# year
# 2011   84.000000
# 2012  129.666667
# 2013  424.135897
# 2014  417.881090
# 2015  408.878956
# 2016  400.367264
# 2017  406.340723

# %%
cars[cars["make"] == "Audi"].groupby("year").agg({"cylinders":"max"})
# Out:
#       cylinders
# year
# 1984        5.0
# 1985        5.0
# 1986        5.0
# 1987        5.0
# 1988        5.0
# 1989        5.0
# 1990        8.0
# 1991        8.0
# 1992        8.0
# 1993        8.0
# 1994        8.0
# 1995        6.0
# 1996        6.0
# 1997        8.0
# 1998        8.0
# 1999        8.0
# 2000        8.0
# 2001        8.0
# 2002        8.0
# 2003        8.0
# 2004        8.0
# 2005       12.0
# 2006       12.0
# 2007       12.0
# 2008       12.0
# 2009       12.0
# 2010       10.0
# 2011       10.0
# 2012       12.0
# 2013       12.0
# 2014       12.0
# 2015       12.0
# 2016       12.0
# 2017       10.0

# %%
cars.describe()
# Out:
#                 co2          year     cylinders
# count  37843.000000  37843.000000  37720.000000
# mean      61.503713   2000.064398      5.737990
# std      153.387715     10.390588      1.751795
# min       -1.000000   1984.000000      2.000000
# 25%       -1.000000   1990.000000      4.000000
# 50%       -1.000000   2001.000000      6.000000
# 75%       -1.000000   2009.000000      6.000000
# max      847.000000   2017.000000     16.000000

# %%
cars_with_co2_measure
# Out:
#              make                    model  co2  year tipo_trany_2  \
# 23043   Chevrolet                     Volt   84  2011   Automatico
# 23746   Chevrolet                     Volt   87  2012   Automatico
# 24396      Nissan                     GT-R  471  2013   Automatico
# 24397  Volkswagen                       CC  349  2013   Automatico
# 24398  Volkswagen                       CC  429  2013   Automatico
# ...           ...                      ...  ...   ...          ...
# 30965      Jaguar                   F-Pace  352  2017   Automatico
# 30966      Nissan           Pathfinder 4WD  404  2017   Automatico
# 30967      Nissan  Pathfinder 4WD Platinum  415  2017   Automatico
# 30968       Lexus              RX 450h AWD  297  2017   Automatico
# 30970         BMW             X5 xDrive40e  248  2017   Automatico
#
#                          fuelType  cylinders
# 23043  Premium Gas or Electricity        4.0
# 23746  Premium Gas or Electricity        4.0
# ...

# %%
co2_cars = cars[cars.co2 >= 0]

# %%
co2_cars
# Out:
#          make                            model  co2  year    tipo_trany_2  \
# 7138   Nissan                         Altra EV    0  2000  no-transmision
# 7139   Toyota                          RAV4 EV    0  2000  no-transmision
# 8143   Toyota                          RAV4 EV    0  2001  no-transmision
# 8144     Ford                            Th!nk    0  2001  no-transmision
# 8146     Ford           Explorer USPS Electric    0  2001  no-transmision
# ...       ...                              ...  ...   ...             ...
# 30970     BMW                     X5 xDrive40e  248  2017      Automatico
# 30972   Tesla  Model S (60 kW-hr battery pack)    0  2016      Automatico
# 30973   Tesla                Model S AWD - 60D    0  2016      Automatico
# 30974   Tesla              Model S AWD - P100D    0  2016      Automatico
# 30975   Tesla                Model X AWD - 60D    0  2016      Automatico
#
#                       fuelType  cylinders
# ...

# %%
co2_cars["co2_label"] = pd.cut(co2_cars.co2,bins=[-1,10,100,200,800] ,labels=["0","eco","B","C"])
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
co2_cars
# Out:
#          make                            model  co2  year    tipo_trany_2  \
# 7138   Nissan                         Altra EV    0  2000  no-transmision
# 7139   Toyota                          RAV4 EV    0  2000  no-transmision
# 8143   Toyota                          RAV4 EV    0  2001  no-transmision
# 8144     Ford                            Th!nk    0  2001  no-transmision
# 8146     Ford           Explorer USPS Electric    0  2001  no-transmision
# ...       ...                              ...  ...   ...             ...
# 30970     BMW                     X5 xDrive40e  248  2017      Automatico
# 30972   Tesla  Model S (60 kW-hr battery pack)    0  2016      Automatico
# 30973   Tesla                Model S AWD - 60D    0  2016      Automatico
# 30974   Tesla              Model S AWD - P100D    0  2016      Automatico
# 30975   Tesla                Model X AWD - 60D    0  2016      Automatico
#
#                       fuelType  cylinders co2_label
# ...

# %%
cars_make_analyis = co2_cars.groupby(["make","co2_label"]).agg({"co2_label":"count"})

# %%
cars_make_analyis.loc["Audi"]
# Out:
#            co2_label
# co2_label
# 0                  0
# eco                0
# B                  2
# C                221

# %%
cars_make_analyis.loc["Chevrolet"]
# Out:
#            co2_label
# co2_label
# 0                  5
# eco                7
# B                  2
# C                396

# %%
co2_cars.groupby(["year","co2_label"]).agg({"co2_label":"count"})
# Out:
#                 co2_label
# year co2_label
# 1998 0                  3
#      eco                0
#      B                  0
#      C                  0
# 1999 0                  7
#      eco                0
#      B                  0
#      C                  0
# 2000 0                  4
#      eco                0
#      B                  0
#      C                  0
# 2001 0                  5
#      eco                0
#      B                  0
#      C                  0
# 2002 0                  2
#      eco                0
#      B                  0
#      C                  0
# 2003 0                  1
#      eco                0
#      B                  0
#      C                  0
# 2008 0                  1
#      eco                0
#      B                  0
#      C                  0
# 2011 0                  4
#      eco                1
#      B                  0
#      C                  0
# 2012 0                  9
#      eco                1
# ...

# %%
co2_cars.fuelType.value_counts()
# Out:
# Premium                        2512
# Regular                        2465
# Gasoline or E85                 420
# Diesel                          130
# Electricity                     120
# Premium or E85                   88
# Midgrade                         58
# Premium and Electricity          20
# Premium Gas or Electricity       17
# Regular Gas and Electricity      16
# CNG                               4
# Regular Gas or Electricity        2
# Gasoline or natural gas           2
# Name: fuelType, dtype: int64

# %%
def fuelType(x):
    if x in ["Premium","Regular","Gasoline or E85","Premium or E85","Gasoline or natural gas"]:
        return "Gasoline"
    elif x in ["Diesel","CNG"]:
        return "Diesel"
    elif x in ["Electricity","Premium and Electricity","Regular Gas and Electricity","Regular Gas or Electricity"]:
        return "Hybrid"
    
    return "Others"


co2_cars["fuel_label"] = co2_cars.fuelType.apply(fuelType)
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':

# %%
co2_cars[co2_cars.fuel_label == "Hybrid"].groupby(["year","make"]).agg({"make":"count"})
# Out:
#                     make
# year make
# 1998 Chevrolet         2
#      Honda             1
# 1999 Dodge             1
#      Ford              2
#      GMC               2
# ...                  ...
# 2017 Hyundai           1
#      Kia               1
#      Mercedes-Benz     1
#      Mitsubishi        1
#      Volvo             1
#
# [92 rows x 1 columns]

# %%
def change(q):
    return f"make:{q.make} model:{q.model}"

co2_cars["title"] = co2_cars.apply(change, axis=1)
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
co2_cars
# Out:
#          make                            model  co2  year    tipo_trany_2  \
# 7138   Nissan                         Altra EV    0  2000  no-transmision
# 7139   Toyota                          RAV4 EV    0  2000  no-transmision
# 8143   Toyota                          RAV4 EV    0  2001  no-transmision
# 8144     Ford                            Th!nk    0  2001  no-transmision
# 8146     Ford           Explorer USPS Electric    0  2001  no-transmision
# ...       ...                              ...  ...   ...             ...
# 30970     BMW                     X5 xDrive40e  248  2017      Automatico
# 30972   Tesla  Model S (60 kW-hr battery pack)    0  2016      Automatico
# 30973   Tesla                Model S AWD - 60D    0  2016      Automatico
# 30974   Tesla              Model S AWD - P100D    0  2016      Automatico
# 30975   Tesla                Model X AWD - 60D    0  2016      Automatico
#
#                       fuelType  cylinders co2_label fuel_label  \
# ...
