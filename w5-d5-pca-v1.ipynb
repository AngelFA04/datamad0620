# %%
from sklearn.datasets import fetch_openml
X, y = fetch_openml('mnist_784', version=1, return_X_y=True)

# %%
X.shape
# Out:
# (70000, 784)

# %%
# Groundtruth
y.shape
# Out:
# (70000,)

# %%
X[0].shape
# Out:
# (784,)

# %%
y[0]
# Out:
# '5'

# %%
numberImage = X[0].reshape((28,28))
print(numberImage.shape)
# Out:
# (28, 28)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

plt.imshow(numberImage, cmap="gray")

# %%
for i in range(10):
    im = X[i].reshape((28,28))
    plt.figure()
    plt.title(f"Groundtruth={y[i]}")
    plt.imshow(im, cmap="gray")

# %%
import numpy as np

x1 = np.random.randn(1000)-2
y1 = np.random.randn(1000)-2

x2 = np.random.randn(1000)+2
y2 = np.random.randn(1000)+2


plt.plot(x1,y1,'o')
plt.plot(x2,y2,'o')

# %%
import seaborn as sns
import pandas as pd

xz = np.concatenate([np.random.randn(1000)+10,np.random.randn(1000)])
yz = np.concatenate([np.random.randn(1000),np.random.randn(1000)])

df = pd.DataFrame({"x":xz,"y":yz})
sns.jointplot(x="x", y="y", data=df, kind="kde");

# %%
from sklearn.decomposition import PCA


pca = PCA(n_components=2)
data2d = pca.fit_transform(X)

# %%
data2d.shape
# Out:
# (70000, 2)

# %%
data2d[:10]
# Out:
# array([[ 122.25654427, -316.24580497],
#        [1010.49518089, -289.97198979],
#        [ -58.99551683,  393.69449022],
#        [-796.96416816, -607.41681111],
#        [-391.32079339,  729.80118754],
#        [ 185.96510998,  223.86309963],
#        [-730.48813796, -161.99828292],
#        [ 503.48722163, -308.7490127 ],
#        [-874.55459127,  -84.30377875],
#        [-304.01726725,  463.57864549]])

# %%
idx1 = np.where(y=='1')
idx8 = np.where(y=='8')
print(idx1[0].shape,idx8[0].shape)
# Out:
# (7877,) (6825,)

# %%
idx1[:10]
# Out:
# (array([    3,     6,     8, ..., 69978, 69984, 69994]),)

# %%
one = X[idx8]

for i,x in enumerate(one):
    plt.figure()
    plt.imshow(x.reshape((28,28)), cmap="gray")
    if i > 5:
        break

# %%
idx1 = np.where(y=='1')
idx8 = np.where(y=='8')
one = data2d[idx1]
eight = data2d[idx8]

plt.scatter(one[:,0],one[:,1],alpha=0.1)
plt.scatter(eight[:,0],eight[:,1],alpha=0.1)
plt.legend(["One","Eight"])

# %% [markdown]
# # References
# - https://setosa.io/ev/principal-component-analysis/
